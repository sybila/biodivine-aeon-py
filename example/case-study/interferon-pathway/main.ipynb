# %% [markdown]
# ## Drug Induced Effects on Interferon Signalling
#
# In this case study, we focus on a Boolean network which models a complex human cell signalling pathway, describing the activity of type-1 interferons and related molecules interacting with the SARS-COV-2 virion. The network is designed to explain the dynamics of *innate immune response* (**IIR**) -- an important biological phenotype corresponding to the activity of the immune system, and *inflammation* (**INFL**) -- a biological phenotype causing an overreaction that might cause severe health problems in affected tissues (e.g., cytokine storm \[1]).
#
# We have adopted the BN model of interferon type-1 pathway produced by the COVID-19 Disease Map project \[2]. The original BN model has been constructed from the openly accessible [SBGN curated pathway](https://fairdomhub.org/models/713) by employing the automated inference algorithm CaSQ \[3] (see `interferon-pathway.sbml` available online under revision [51a2374f](https://git-r3lab.uni.lu/covid/models/-/blob/master/Executable%20Modules/SBML_qual_build/sbml/Interferon1_stable.sbml)). CaSQ is producing ready-to-simulate (non-parametrised) BNs. Logical parameters here represent input variables.
#
# The original BN model contains 68 variables, 190 regulations, and 53 logical parameters. The parameters can be classified into three groups: virus proteins, input signals, and drugs (`Azithromycin_drug`, `GRL0617_drug`, and `MNS_drug`). The phenotypes expressed by the actual cell are represented through special output variables: `ISG_expression_antiviral_response_phenotype` (or **IIR**), `Proinflammatory_cytokine_expression_Inflammation_phenotype` (or **INFL**), and `type_I_IFN_response_phenotype` (or **IFN**).

# %% [markdown]
# ### Parameter induced multi-stability
#
# Due to the large parameter space, computing the network attractors can take several minutes, but is nevertheless feasible using common hardware:

# %%
from pandas import DataFrame
from biodivine_aeon import *
# Out:
# Detected IPython (`ZMQInteractiveShell`). Log level set to `LOG_ESSENTIAL`.

# %%
model = BooleanNetwork.from_file('interferon-pathway.sbml')
model = model.inline_inputs() # Turn input variables into explicit parameters. Improves performance.
graph = AsynchronousGraph(model)
print(model)
# Out:
# BooleanNetwork(variables=68, regulations=97, explicit_parameters=53, implicit_parameters=0)

# %%
attractors = Attractors.attractors(graph)
# Out:
# Start interleaved transition guided reduction with 2658455991569832000000000000000000000[nodes:2] candidates.
#  > Discarded 1329227995784916000000000000000000000 instances based on the BnVariable(24) extended component.
#  > State space reduced to 1329227995784916000000000000000000000[nodes:5].
#  > Discarded 664613997892458000000000000000000000 instances based on the BnVariable(54) extended component.
#  > State space reduced to 664613997892458000000000000000000000[nodes:9].
#  > Discarded 332306998946229000000000000000000000 instances based on the BnVariable(31) extended component.
#  > State space reduced to 332306998946229000000000000000000000[nodes:12].
#  > Discarded 166153499473114500000000000000000000 instances based on the BnVariable(5) extended component.
#  > State space reduced to 166153499473114500000000000000000000[nodes:16].
#  > Discarded 83076749736557240000000000000000000 instances based on the BnVariable(61) extended component.
#  > State space reduced to 83076749736557240000000000000000000[nodes:23].
#  > Discarded 41538374868278620000000000000000000 instances based on the BnVariable(30) extended component.
#  > State space reduced to 41538374868278620000000000000000000[nodes:35].
#  > Discarded 20769187434139310000000000000000000 instances based on the BnVariable(2) extended component.
#  > State space reduced to 20769187434139310000000000000000000[nodes:49].
#  > Discarded 10384593717069655000000000000000000 instances based on the BnVariable(59) extended component.
#  > State space reduced to 10384593717069655000000000000000000[nodes:66].
#  > Discarded 5192296858534828000000000000000000 instances based on the BnVariable(27) extended component.
#  > State space reduced to 5192296858534828000000000000000000[nodes:69].
#  > Discarded 2596148429267414000000000000000000 instances based on the BnVariable(55) extended component.
#  > State space reduced to 2596148429267414000000000000000000[nodes:86].
#  > Discarded 1304016326822276700000000000000000 instances based on the BnVariable(49) extended component.
#  > State space reduced to 1292132102445137100000000000000000[nodes:130].
#  > Discarded 0 instances using the BnVariable(53) transition basin.
#  > Discarded 645471840003711560000000000000000 instances based on the BnVariable(53) extended component.
#  > State space reduced to 646660262441425500000000000000000[nodes:171].
#  > Discarded 0 instances using the BnVariable(52) transition basin.
#  > Discarded 322141708782998800000000000000000 instances based on the BnVariable(52) extended component.
#  > State space reduced to 324518553658426730000000000000000[nodes:181].
#  > Discarded 162259276829213360000000000000000 instances based on the BnVariable(13) extended component.
#  > State space reduced to 162259276829213360000000000000000[nodes:237].
#  > Discarded 81129638414606680000000000000000 instances based on the BnVariable(62) extended component.
#  > State space reduced to 81129638414606680000000000000000[nodes:253].
#  > Discarded 40564819207303340000000000000000 instances based on the BnVariable(63) extended component.
#  > State space reduced to 40564819207303340000000000000000[nodes:255].
#  > Discarded 20282409603651670000000000000000 instances based on the BnVariable(64) extended component.
#  > State space reduced to 20282409603651670000000000000000[nodes:257].
#  > Discarded 10141204801825835000000000000000 instances based on the BnVariable(25) extended component.
#  > State space reduced to 10141204801825835000000000000000[nodes:292].
#  > Discarded 5070602400912918000000000000000 instances based on the BnVariable(32) extended component.
#  > State space reduced to 5070602400912918000000000000000[nodes:516].
#  > Discarded 2535301200456459000000000000000 instances based on the BnVariable(43) extended component.
#  > State space reduced to 2535301200456459000000000000000[nodes:543].
#  > Discarded 1267650600228229400000000000000 instances based on the BnVariable(47) extended component.
#  > State space reduced to 1267650600228229400000000000000[nodes:1000].
#  > Finished ITGR process. 47 processes remaining.
#  > Discarded 633825300114114700000000000000 instances based on the BnVariable(46) extended component.
#  > Finished ITGR process. 46 processes remaining.
#  > State space reduced to 633825300114114700000000000000[nodes:1168].
#  > Finished ITGR process. 46 processes remaining.
#  > Finished ITGR process. 46 processes remaining.
#  > Discarded 475371471762877500000000000000 instances based on the BnVariable(7) extended component.
#  > Finished ITGR process. 45 processes remaining.
#  > State space reduced to 158453828351237200000000000000[nodes:1891].
#  > Discarded 689614315000805700000000 instances using the BnVariable(8) transition basin.
#  > Finished ITGR process. 45 processes remaining.
#  > State space reduced to 158453138736922200000000000000[nodes:2108].
#  > Discarded 0 instances based on the BnVariable(8) extended component.
#  > Finished ITGR process. 44 processes remaining.
#  > Discarded 79226569365015840000000000000 instances based on the BnVariable(66) extended component.
#  > Finished ITGR process. 43 processes remaining.
#  > State space reduced to 79226569371906350000000000000[nodes:2108].
#  > Discarded 0 instances using the BnVariable(11) transition basin.
#  > Finished ITGR process. 43 processes remaining.
#  > Discarded 39613284682507920000000000000 instances based on the BnVariable(11) extended component.
#  > Finished ITGR process. 42 processes remaining.
#  > State space reduced to 39613284689398430000000000000[nodes:2121].
#  > Finished ITGR process. 42 processes remaining.
#  > Discarded 19806642341253960000000000000 instances based on the BnVariable(10) extended component.
#  > Finished ITGR process. 41 processes remaining.
#  > State space reduced to 19806642348144468000000000000[nodes:2134].
#  > Discarded 9903321170626980000000000000 instances based on the BnVariable(65) extended component.
#  > Finished ITGR process. 40 processes remaining.
#  > State space reduced to 9903321177517488000000000000[nodes:2127].
#  > Discarded 382366163675381760 instances using the BnVariable(60) transition basin.
#  > Finished ITGR process. 40 processes remaining.
#  > State space reduced to 9903321177135122000000000000[nodes:2110].
#  > Discarded 2475830292451906000000000000 instances based on the BnVariable(60) extended component.
#  > Finished ITGR process. 39 processes remaining.
#  > State space reduced to 7427490884683215000000000000[nodes:2113].
#  > Discarded 3713745442341608000000000000 instances based on the BnVariable(67) extended component.
#  > Finished ITGR process. 38 processes remaining.
#  > State space reduced to 3713745442341608000000000000[nodes:2114].
#  > Finished ITGR process. 38 processes remaining.
#  > Discarded 1856872721170804000000000000 instances based on the BnVariable(6) extended component.
#  > Finished ITGR process. 37 processes remaining.
#  > State space reduced to 1856872721170804000000000000[nodes:2130].
#  > Finished ITGR process. 37 processes remaining.
#  > Discarded 928436360585402000000000000 instances based on the BnVariable(9) extended component.
#  > Finished ITGR process. 36 processes remaining.
#  > State space reduced to 928436360585402000000000000[nodes:2146].
#  > Discarded 464218180292701000000000000 instances based on the BnVariable(26) extended component.
#  > Finished ITGR process. 35 processes remaining.
#  > State space reduced to 464218180292701000000000000[nodes:2214].
#  > Discarded 0 instances using the BnVariable(58) transition basin.
#  > Finished ITGR process. 35 processes remaining.
#  > Discarded 284697363299586850000000000 instances based on the BnVariable(20) extended component.
#  > Finished ITGR process. 34 processes remaining.
#  > State space reduced to 179520816993114100000000000[nodes:3074].
#  > Discarded 88853714131846090000000000 instances based on the BnVariable(45) extended component.
#  > Finished ITGR process. 33 processes remaining.
#  > State space reduced to 90667102861268030000000000[nodes:3854].
#  > Discarded 0 instances using the BnVariable(23) transition basin.
#  > Finished ITGR process. 33 processes remaining.
#  > Discarded 43520162701212070000000000 instances based on the BnVariable(23) extended component.
#  > Finished ITGR process. 32 processes remaining.
#  > State space reduced to 47146940160055960000000000[nodes:4292].
#  > Finished ITGR process. 32 processes remaining.
#  > Finished ITGR process. 32 processes remaining.
#  > Discarded 21760081350606035000000000 instances based on the BnVariable(21) extended component.
#  > Finished ITGR process. 31 processes remaining.
#  > State space reduced to 25386858809449923000000000[nodes:4416].
#  > Discarded 10880040675303018000000000 instances based on the BnVariable(19) extended component.
#  > Finished ITGR process. 30 processes remaining.
#  > State space reduced to 14506818134146905000000000[nodes:4557].
#  > Finished ITGR process. 30 processes remaining.
#  > Discarded 9067536079019324000000000 instances based on the BnVariable(3) extended component.
#  > Finished ITGR process. 29 processes remaining.
#  > State space reduced to 5439282055127581000000000[nodes:4954].
#  > Finished ITGR process. 29 processes remaining.
#  > Discarded 3211264843584253600000000 instances based on the BnVariable(22) extended component.
#  > Finished ITGR process. 28 processes remaining.
#  > State space reduced to 2228017211543327500000000[nodes:5844].
#  > Discarded 20331872668090370 instances using the BnVariable(44) transition basin.
#  > Finished ITGR process. 28 processes remaining.
#  > State space reduced to 2228017191211454800000000[nodes:5842].
#  > Discarded 1114008583887828800000000 instances based on the BnVariable(44) extended component.
#  > Finished ITGR process. 27 processes remaining.
#  > State space reduced to 1114008607323626000000000[nodes:8402].
#  > Finished ITGR process. 27 processes remaining.
#  > Discarded 557004291943914400000000 instances based on the BnVariable(29) extended component.
#  > Finished ITGR process. 26 processes remaining.
#  > State space reduced to 557004315379711600000000[nodes:9111].
#  > Discarded 278502145971957200000000 instances based on the BnVariable(48) extended component.
#  > Finished ITGR process. 25 processes remaining.
#  > State space reduced to 278502169407754400000000[nodes:10223].
#  > Discarded 0 instances using the BnVariable(56) transition basin.
#  > Finished ITGR process. 25 processes remaining.
#  > Discarded 146285836833539700000000 instances based on the BnVariable(56) extended component.
#  > Finished ITGR process. 24 processes remaining.
#  > State space reduced to 132216332574214700000000[nodes:11616].
#  > Discarded 0 instances using the BnVariable(18) transition basin.
#  > Finished ITGR process. 24 processes remaining.
#  > Discarded 66107846897605684000000 instances based on the BnVariable(18) extended component.
#  > Finished ITGR process. 23 processes remaining.
#  > State space reduced to 66108485676609020000000[nodes:11429].
#  > Discarded 31305539078892888000000 instances based on the BnVariable(58) extended component.
#  > Finished ITGR process. 22 processes remaining.
#  > State space reduced to 34802946597716136000000[nodes:11677].
#  > Finished ITGR process. 22 processes remaining.
#  > Discarded 17401295330960030000000 instances based on the BnVariable(17) extended component.
#  > Finished ITGR process. 21 processes remaining.
#  > State space reduced to 17401651266756106000000[nodes:11822].
#  > Finished ITGR process. 21 processes remaining.
#  > Discarded 5606109998284460000000 instances based on the BnVariable(4) extended component.
#  > Finished ITGR process. 20 processes remaining.
#  > State space reduced to 11795541268471646000000[nodes:12496].
#  > Discarded 0 instances using the BnVariable(16) transition basin.
#  > Finished ITGR process. 20 processes remaining.
#  > Discarded 5897338602821467000000 instances based on the BnVariable(16) extended component.
#  > Finished ITGR process. 19 processes remaining.
#  > State space reduced to 5898202665650179000000[nodes:13021].
#  > Discarded 3685476740904029000000 instances based on the BnVariable(15) extended component.
#  > Finished ITGR process. 18 processes remaining.
#  > State space reduced to 2212725924746150000000[nodes:12792].
#  > Finished ITGR process. 18 processes remaining.
#  > Discarded 737527211212071200000 instances based on the BnVariable(14) extended component.
#  > Finished ITGR process. 17 processes remaining.
#  > State space reduced to 1475198713534078800000[nodes:12719].
#  > Discarded 732305709656600200000 instances based on the BnVariable(42) extended component.
#  > Finished ITGR process. 16 processes remaining.
#  > State space reduced to 742893003877478600000[nodes:13315].
#  > Discarded 369177796034265350000 instances based on the BnVariable(39) extended component.
#  > Finished ITGR process. 15 processes remaining.
#  > State space reduced to 373715207843213200000[nodes:13718].
#  > Discarded 184588898017132680000 instances based on the BnVariable(40) extended component.
#  > Finished ITGR process. 14 processes remaining.
#  > State space reduced to 189126309826080540000[nodes:14121].
#  > Discarded 92294449008566340000 instances based on the BnVariable(41) extended component.
#  > Finished ITGR process. 13 processes remaining.
#  > State space reduced to 96831860817514200000[nodes:13890].
#  > Discarded 0 instances using the BnVariable(33) transition basin.
#  > Finished ITGR process. 13 processes remaining.
#  > Discarded 41501782409403950000 instances based on the BnVariable(33) extended component.
#  > Finished ITGR process. 12 processes remaining.
#  > State space reduced to 55330078408110250000[nodes:14251].
#  > Discarded 27665039150368555000 instances based on the BnVariable(36) extended component.
#  > Finished ITGR process. 11 processes remaining.
#  > State space reduced to 27665039257741697000[nodes:14630].
#  > Discarded 13832519575184278000 instances based on the BnVariable(37) extended component.
#  > Finished ITGR process. 10 processes remaining.
#  > State space reduced to 13832519682557420000[nodes:15009].
#  > Discarded 6916259787592139000 instances based on the BnVariable(34) extended component.
#  > Finished ITGR process. 9 processes remaining.
#  > State space reduced to 6916259894965281000[nodes:15388].
#  > Discarded 3458129893796069400 instances based on the BnVariable(38) extended component.
#  > Finished ITGR process. 8 processes remaining.
#  > State space reduced to 3458130001169211400[nodes:15767].
#  > Discarded 1729064946898034700 instances based on the BnVariable(35) extended component.
#  > Finished ITGR process. 7 processes remaining.
#  > State space reduced to 1729065054271176700[nodes:16146].
#  > Discarded 902377378321006600 instances based on the BnVariable(57) extended component.
#  > Finished ITGR process. 6 processes remaining.
#  > State space reduced to 826687675950170100[nodes:24924].
#  > Discarded 0 instances using the BnVariable(50) transition basin.
#  > Finished ITGR process. 6 processes remaining.
#  > Discarded 461019919899688960 instances based on the BnVariable(50) extended component.
#  > Finished ITGR process. 5 processes remaining.
#  > State space reduced to 365667756050481150[nodes:32529].
#  > Discarded 176517479202553860 instances based on the BnVariable(51) extended component.
#  > Finished ITGR process. 4 processes remaining.
#  > State space reduced to 189150276847927300[nodes:29904].
#  > Discarded 0 instances using the BnVariable(12) transition basin.
#  > Finished ITGR process. 4 processes remaining.
#  > Discarded 54060560819421180 instances based on the BnVariable(12) extended component.
#  > Finished ITGR process. 3 processes remaining.
#  > State space reduced to 135089716028506110[nodes:29141].
#  > Discarded 0 instances using the BnVariable(28) transition basin.
#  > Discarded 67544851070451710 instances based on the BnVariable(28) extended component.
#  > Finished ITGR process. 2 processes remaining.
#  > State space reduced to 67544864958054400[nodes:31459].
#  > Discarded 0 instances using the BnVariable(0) transition basin.
#  > Discarded 33772265872031744 instances based on the BnVariable(0) extended component.
#  > State space reduced to 33772599086022656[nodes:35489].
#  > Discarded 16886299516469248 instances based on the BnVariable(1) extended component.
# Interleaved transition guided reduction finished with 16886299569553408[nodes:35277] candidates.
# Start Xie-Beerel attractor detection on 16886299569553408[nodes:35277] candidates.
#  > Found a bottom SCC: 10896x9007199254740992[nodes:5474].
#  > Found a bottom SCC: 28704x5629499534213120[nodes:26380].
#  > Found a bottom SCC: 18520x1125899897012224[nodes:19846].
#  > Found a bottom SCC: 16240x1123700883587072[nodes:14486].
# Attractor detection finished with 4 results.

# %% [markdown]
# The automatically generated decision tree for these attractor sets is actually quite manageable (only roughly `50` decision nodes), but it is very deep and thus does not fit onto a single page. A composited screenshot of the original full decision tree is available in `full-tree.png`. A compact representation of the tree is also drawn in the `full-tree.pdf` file.

# %% [markdown]
# <p align="center">
#     <img src="tree-full.png">
# </p>

# %% [markdown]
# #### Phenotypes are not correlated with multi-stability
#
# Interestingly, from the logical parameters representing drugs, only the `Azithromycin_drug` was chosen by the automatic tree generation algorithm as relevant. Furthermore, if we perform stability analysis on the individual tree nodes, we can notice that the expression of phenotypes is not tied to the number (or types) of attractors, as we for example see in the T-cell survival case study.
#
# In particular, the decision tree in `tree-full.pdf` shows the ratio of parametrisations exhibiting the **INFL** phenotype in each leaf node. We see that initially, most decisions do not impact the ratio of parametrisations expressing this phenotype (all nodes stay at `25%`). Only once we condition on `E`, we see some variability. However, even in this case, we do not see a clear "appearance" or "disappearance" of an attractor corresponding to an inflammation phenotype.
#
# Similarly, for **IIR** there is also no clear relationship between mutli-stability, and the presence of immune response.
#
# Finally, the **IFN** phenotype is not expressed in any attractor of the network for any parametrisation (see below). This is unexpected as it is one of the primary outputs of this network. *At this point, we attribute this to a model error and disregard this phenotype in further analysis.*

# %%
# Note that this number does not necessarily mean there are 4 unique attractors
# in some parametrisation. The attractor detection algorithm creates the
# sets opportunistically and does not guarantee that the result is in any sense
# minimal. It is only guaranteed to be correct in the sense that each
# returned set contains exactly one attractor for every included color.
print("Attractor set count:", len(attractors))

attrStates = graph.mk_empty_colored_vertices();
for attr in attractors:
    attrStates = attrStates.union(attr)

print("Unique attr. states:", int(attrStates.vertices().cardinality()))

IIR = graph.mk_subspace({"ISG_expression_antiviral_response_phenotype": True})
INFL = graph.mk_subspace({"Proinflammatory_cytokine_expression_Inflammation_phenotype": True})
IFN = graph.mk_subspace({"type_I_IFN_response_phenotype": True})

attrIIR = attrStates.intersect(IIR)
attrINFL = attrStates.intersect(INFL)
attrIFN = attrStates.intersect(IFN)

print("IIR phenotype colors:", int(attrIIR.colors().cardinality()))
print("INFL phenotype colors:", int(attrINFL.colors().cardinality()))
print("IFN phenotype colors:", int(attrIFN.colors().cardinality()))
# Out:
# Attractor set count: 4
# Unique attr. states: 59000
# IIR phenotype colors: 6756498952683520
# INFL phenotype colors: 2251947990056960
# IFN phenotype colors: 0

# %% [markdown]
# ### Logical parameters driving network phenotypes
#
# To better understand the impact of individual parameters on the network phenotypes, we can manually compute the distribution of relevant parametrisations for each phenotype. In the following, we measure how much a network parameter impacts the expression of a particular phenotype. The number describes a change in the number of parametrisations which express the phenotype with the parameter absent or present. That is, a change of `+75%` for parameter `X` means that fixing `X = true` increases the ratio of parameters expressing a particular phenotype by `75%` compared to cases where `X = false` (e.g. `10%` when `X = false` and `85%` when `X = true`).
#
# Note that due to the high number of parameters, this computation can also take several minutes.

# %%
def phenotype_ratio(attr, phenotype):
    """The ratio of the phenotype colors compared to all colors in the attr set."""
    return attr.intersect(phenotype).colors().cardinality() / attr.colors().cardinality()

def check_impact(attr, param, phenotype):
    """Compute the impact of the set of param colors on the expression of phenotype in the attr set."""
    attr_param_on = attr.intersect_colors(param)
    attr_param_off = attr.minus_colors(param)
    ratio_on = phenotype_ratio(attr_param_on, phenotype)
    ratio_off = phenotype_ratio(attr_param_off, phenotype)
    return (ratio_on - ratio_off) * 100.0

table = []
# Note that the model inputs are now represented as parameters, since we transformed
# the model using the `inline_inputs` function.
for i in model.explicit_parameters():
    i_true = graph.mk_function_colors(i, "true")
    i_name = model.get_explicit_parameter_name(i)
    iir_impact = check_impact(attrStates, i_true, IIR)
    infl_impact = check_impact(attrStates, i_true, INFL)
    print(f"Impact of {i_name}: {iir_impact} (IIR) {infl_impact} (INFL)")
    if iir_impact != 0 or infl_impact != 0:
        table.append([i_name, iir_impact, infl_impact])
# Out:
# Impact of NEMO: 0.0 (IIR) 0.0032901763916015625 (INFL)
# Impact of NFKB1: 0.0 (IIR) 0.0032901763916015625 (INFL)
# Impact of TAK1: 0.0 (IIR) 0.0032901763916015625 (INFL)
# Impact of M: -0.0244140625 (IIR) 0.0 (INFL)
# Impact of Orf7b: -0.0244140625 (IIR) 0.0 (INFL)
# Impact of TRIM25: 0.0 (IIR) 0.0 (INFL)
# Impact of pp1ab: 0.0 (IIR) 0.0 (INFL)
# Impact of Nsp1: -0.0244140625 (IIR) 0.0 (INFL)
# Impact of Nsp10: 0.0 (IIR) 0.0 (INFL)
# Impact of N: 0.0 (IIR) 0.0 (INFL)
# Impact of TLR9: 0.0 (IIR) 0.0001430511474609375 (INFL)
# Impact of Nsp14: 0.0 (IIR) 0.0 (INFL)
# Impact of sa3_IFNB1_extracellular_space: 0.0 (IIR) 0.0 (INFL)
# Impact of MYD88: 0.0 (IIR) 0.0032901763916015625 (INFL)
# Impact of IkB: 0.0 (IIR) 0.0032901763916015625 (INFL)
# Impact of JAK1: 0.0 (IIR) 0.0 (INFL)
# Impact of RIP1: 0.0 (IIR) 0.0032901763916015625 (INFL)
# Impact of Nsp3: -49.9755859375 (IIR) -0.0032901763916015625 (INFL)
# Impact of MAPK8: 0.0 (IIR) 0.0 (INFL)
# Impact of Viral_dsRNA_rna_endosome: 0.0 (IIR) 0.0012874603271484375 (INFL)
# Impact of TREML4: 0.0244140625 (IIR) 0.0001430511474609375 (INFL)
# Impact of FOS: 0.0 (IIR) 0.0 (INFL)
# Impact of Nsp6: -0.0244140625 (IIR) 0.0 (INFL)
# Impact of TLR7: 0.0 (IIR) 0.0001430511474609375 (INFL)
# Impact of RELA: 0.0 (IIR) 0.0032901763916015625 (INFL)
# Impact of JUN: 0.0 (IIR) 0.0 (INFL)
# Impact of Nsp15: 0.0 (IIR) 0.0 (INFL)
# Impact of Orf3a: -0.0244140625 (IIR) 0.0 (INFL)
# Impact of Orf6: -0.0244140625 (IIR) 0.0 (INFL)
# Impact of Nsp5: -0.0244140625 (IIR) 0.0 (INFL)
# Impact of TAB2: 0.0 (IIR) 0.0032901763916015625 (INFL)
# Impact of IRF9: 0.0244140625 (IIR) 0.0 (INFL)
# Impact of TRIF: 0.0 (IIR) 0.0032901763916015625 (INFL)
# Impact of Azithromycin_drug: 49.9755859375 (IIR) 0.0010013580322265625 (INFL)
# Impact of sa5_IFNA1_extracellular_space: 0.0 (IIR) 0.0 (INFL)
# Impact of IFNAR_complex: 0.0 (IIR) 0.0 (INFL)
# Impact of Nsp13: -0.0244140625 (IIR) 0.0 (INFL)
# Impact of MNS_drug: 0.0 (IIR) -49.99890327453613 (INFL)
# Impact of Viral_replication_phenotype: 0.0 (IIR) 0.0 (INFL)
# Impact of RNF135: 0.0 (IIR) 0.0 (INFL)
# Impact of E: 0.0 (IIR) 49.99890327453613 (INFL)
# Impact of Nsp16: 0.0 (IIR) 0.0 (INFL)
# Impact of Orf7a: -0.0244140625 (IIR) 0.0 (INFL)
# Impact of IRAK1_4: 0.0 (IIR) 0.0032901763916015625 (INFL)
# Impact of Orf8_complex: 0.0 (IIR) 0.0 (INFL)
# Impact of GRL0617_drug: 0.0 (IIR) 0.0 (INFL)
# Impact of IKKa: 0.0 (IIR) 0.0032901763916015625 (INFL)
# Impact of Orf9b: 0.0 (IIR) -0.0032901763916015625 (INFL)
# Impact of TAB1: 0.0 (IIR) 0.0032901763916015625 (INFL)
# Impact of TANK: 0.0 (IIR) 0.0 (INFL)
# Impact of TYK2: 0.0 (IIR) 0.0 (INFL)
# Impact of MAPK14: 0.0 (IIR) 0.0 (INFL)
# Impact of IKKb: 0.0 (IIR) 0.0032901763916015625 (INFL)

# %%
DataFrame(table, columns=["Variable", "IIR gain", "INFL gain"])
# Out:
#                     Variable   IIR gain  INFL gain
# 0                       NEMO   0.000000   0.003290
# 1                      NFKB1   0.000000   0.003290
# 2                       TAK1   0.000000   0.003290
# 3                          M  -0.024414   0.000000
# 4                      Orf7b  -0.024414   0.000000
# 5                       Nsp1  -0.024414   0.000000
# 6                       TLR9   0.000000   0.000143
# 7                      MYD88   0.000000   0.003290
# 8                        IkB   0.000000   0.003290
# 9                       RIP1   0.000000   0.003290
# 10                      Nsp3 -49.975586  -0.003290
# 11  Viral_dsRNA_rna_endosome   0.000000   0.001287
# 12                    TREML4   0.024414   0.000143
# 13                      Nsp6  -0.024414   0.000000
# 14                      TLR7   0.000000   0.000143
# 15                      RELA   0.000000   0.003290
# 16                     Orf3a  -0.024414   0.000000
# 17                      Orf6  -0.024414   0.000000
# 18                      Nsp5  -0.024414   0.000000
# 19                      TAB2   0.000000   0.003290
# 20                      IRF9   0.024414   0.000000
# 21                      TRIF   0.000000   0.003290
# 22         Azithromycin_drug  49.975586   0.001001
# 23                     Nsp13  -0.024414   0.000000
# 24                  MNS_drug   0.000000 -49.998903
# 25                         E   0.000000  49.998903
# 26                     Orf7a  -0.024414   0.000000
# 27                   IRAK1_4   0.000000   0.003290
# 28                      IKKa   0.000000   0.003290
# 29                     Orf9b   0.000000  -0.003290
# 30                      TAB1   0.000000   0.003290
# 31                      IKKb   0.000000   0.003290

# %% [markdown]
# In this table, we can see that only 32 out of the 53 network parameters actually influence phenotype expression (the ones with no impact are skipped). Furthermore, by the change in expression ratios, we can see which parameter has the highest impact on the network's phenotypes. For example, notice that `Azithromycin_drug` has a high impact on the **IIR** phenotype, while `E` and `MNS_drug` have high impact on **INFL**. Interestingly, `GRL0617_drug` does not appear to influence phenotype expression in any way.
#
# Subsequently, we perform three more experiments, each following different conditions. In the first experiment, we test whether the parameter `Viral_replication_phenotype` has any influence on the impact of other parameters. Parameter `Viral_replication_phenotype` is a major factor in introducing multi-stability (as shown by the decision tree above). We thus want to confirm our hypothesis that the multi-stability caused by this parameter has indeed no effect on network phenotypes.
#
# Additionally, we also test cases where `Azithromycin_drug` is fixed to `true`, and where both `MNS_drug` and `Azithromycin_drug` are fixed to `true`. This should give us a better insight into the influence of these drugs.

# %%
virus_detected = graph.mk_function_colors("Viral_replication_phenotype", "true")
states_virus_on = attrStates.intersect_colors(virus_detected)

table2 = []
for i in model.explicit_parameters():
    i_name = model.get_explicit_parameter_name(i)
    i_true = graph.mk_function_colors(i, "true")
    if i_name == 'Viral_replication_phenotype':
        continue
    iir_impact = check_impact(states_virus_on, i_true, IIR)
    infl_impact = check_impact(states_virus_on, i_true, INFL)
    if iir_impact != 0 or infl_impact != 0:
        table2.append([i_name, iir_impact, infl_impact])

DataFrame(table2, columns=["Variable", "IIR gain", "INFL gain"])
# Out:
#                     Variable   IIR gain  INFL gain
# 0                      Orf3a  -0.024414   0.000000
# 1                      Orf9b   0.000000  -0.003290
# 2                       RIP1   0.000000   0.003290
# 3                       TAB2   0.000000   0.003290
# 4                   MNS_drug   0.000000 -49.998903
# 5                       Nsp3 -49.975586  -0.003290
# 6                      Orf7b  -0.024414   0.000000
# 7                       IKKa   0.000000   0.003290
# 8                      Orf7a  -0.024414   0.000000
# 9                       Nsp6  -0.024414   0.000000
# 10                      Orf6  -0.024414   0.000000
# 11                    TREML4   0.024414   0.000143
# 12                       IkB   0.000000   0.003290
# 13  Viral_dsRNA_rna_endosome   0.000000   0.001287
# 14                      TAB1   0.000000   0.003290
# 15                      IKKb   0.000000   0.003290
# 16                         M  -0.024414   0.000000
# 17                      Nsp1  -0.024414   0.000000
# 18                      RELA   0.000000   0.003290
# 19                      TAK1   0.000000   0.003290
# 20                     Nsp13  -0.024414   0.000000
# 21                      TLR9   0.000000   0.000143
# 22                   IRAK1_4   0.000000   0.003290
# 23                      TLR7   0.000000   0.000143
# 24         Azithromycin_drug  49.975586   0.001001
# 25                         E   0.000000  49.998903
# 26                     MYD88   0.000000   0.003290
# 27                      Nsp5  -0.024414   0.000000
# 28                     NFKB1   0.000000   0.003290
# 29                      TRIF   0.000000   0.003290
# 30                      NEMO   0.000000   0.003290
# 31                      IRF9   0.024414   0.000000

# %%
drug_on = graph.mk_function_colors("Azithromycin_drug", "true")
states_drug_on = attrStates.intersect_colors(drug_on)

table3 = []
for i in model.explicit_parameters():
    i_name = model.get_explicit_parameter_name(i)
    i_true = graph.mk_function_colors(i, "true")
    if i_name == 'Azithromycin_drug':
        continue
    iir_impact = check_impact(states_drug_on, i_true, IIR)
    infl_impact = check_impact(states_drug_on, i_true, INFL)
    if iir_impact != 0 or infl_impact != 0:
        table3.append([i_name, iir_impact, infl_impact])

DataFrame(table3, columns=["Variable", "IIR gain", "INFL gain"])
# Out:
#                     Variable  IIR gain  INFL gain
# 0                          E       0.0  49.998569
# 1                       IKKa       0.0   0.004292
# 2                      NFKB1       0.0   0.004292
# 3                       TAB2       0.0   0.004292
# 4                       RELA       0.0   0.004292
# 5                       TAK1       0.0   0.004292
# 6                       TAB1       0.0   0.004292
# 7                       IKKb       0.0   0.004292
# 8                      Orf9b       0.0  -0.004292
# 9                   MNS_drug       0.0 -49.998569
# 10                      RIP1       0.0   0.004292
# 11                      Nsp3       0.0  -0.004292
# 12                      TLR7       0.0   0.000286
# 13  Viral_dsRNA_rna_endosome       0.0   0.000286
# 14                      NEMO       0.0   0.004292
# 15                       IkB       0.0   0.004292
# 16                      TLR9       0.0   0.000286
# 17                    TREML4       0.0   0.000286
# 18                   IRAK1_4       0.0   0.004292
# 19                     MYD88       0.0   0.004292
# 20                      TRIF       0.0   0.004292

# %%
drug_on = graph.mk_function_colors("MNS_drug", "true")
states_drug_on = states_drug_on.intersect_colors(drug_on)

table4 = []
for i in model.explicit_parameters():
    i_name = model.get_explicit_parameter_name(i)
    i_true = graph.mk_function_colors(i, "true")
    if i_name == 'Azithromycin_drug':
        continue
    if i_name == 'Viral_replication_phenotype':
        continue
    if i_name == 'MNS_drug':
        continue
    iir_impact = check_impact(states_drug_on, i_true, IIR)
    infl_impact = check_impact(states_drug_on, i_true, INFL)
    if iir_impact != 0 or infl_impact != 0:
        table4.append([i_name, iir_impact, infl_impact])

DataFrame(table4, columns=["Variable", "IIR gain", "INFL gain"])
# Out:
#                     Variable  IIR gain  INFL gain
# 0                      MYD88       0.0   0.005722
# 1                       TLR7       0.0   0.000381
# 2                       RIP1       0.0   0.005722
# 3                       TLR9       0.0   0.000381
# 4                       IKKb       0.0   0.005722
# 5                       TAK1       0.0   0.005722
# 6                       NEMO       0.0   0.005722
# 7                     TREML4       0.0   0.000381
# 8                       TAB1       0.0   0.005722
# 9                       TRIF       0.0   0.005722
# 10                      Nsp3       0.0  -0.005722
# 11  Viral_dsRNA_rna_endosome       0.0   0.000381
# 12                       IkB       0.0   0.005722
# 13                      RELA       0.0   0.005722
# 14                      TAB2       0.0   0.005722
# 15                     NFKB1       0.0   0.005722
# 16                   IRAK1_4       0.0   0.005722
# 17                     Orf9b       0.0  -0.005722
# 18                      IKKa       0.0   0.005722

# %% [markdown]
# In the results, we see that `Viral_replication_phenotype` has indeed no effect on the impact of network parameters on its phenotypes (i.e. the numbers are exactly the same). Meanwhile, we see that after applying `Azithromycin_drug`, **IIR** is always active (and thus parameters do not have impact on it any more). Meanwhile, by applying both drugs, the effect of `E` is eliminated as a factor in inflammation. Also note that the impact of other parameters *grows* once we fix either of these two drugs, as opposed to the case of `Viral_replication_phenotype`, where it stayed the same.

# %% [markdown]
# ### Full logical phenotype characterisation
#
# Overall, the previous experiments give us a better overview of which parameters are important for phenotype expression and what is the intensity of their influence. We can now use this information to construct decision trees that actually describe when a certain phenotype is expressed. These trees are constructed in AEON by hand, such that we confirm using stability analysis that each unexpanded node only admits a particular phenotype. The tree screenshots are located in `tree-immune-response.png` and `tree-inflammation.png`, with `tree-immune-response.pdf` and `tree-inflammation.pdf` showing a compacted, more readable (but logically equivalent) version of these trees.
#
# Notice that in both cases, the trees contain exactly the parameters identified in our previous experiments as the ones having impact on the corresponding phenotype. These parameters also appear in an order which follows their observed impact. Also note that while the inflammation tree appears to be much more complex than the immune response tree, the inflammation tree actually contains two equivalent branches, and depends on more parameter values (22 vs. 13).

# %% [markdown]
# ### Discussion
#
# During our analysis of the type-1 interferon pathway, we have discovered several unexpected properties which suggest that the model is incomplete or biologically unsound. In particular, we have shown that the model as is cannot express any activity of interferons (**INF** phenotype) -- one of its main functionalities. Additionally, we showed that replication of the virus inside the cell (i.e. `Viral_replication_phenotype`) does not in any way influence the expression of the two remaining phenotypes.
#
# We also constructed a bifurcation decision tree characterising the presence of different multi-stable behaviour classes. However, in this tree, we do not observe any meaningful correlation between the number of attractors and the expressed network phenotypes.
#
# Nevertheless, we were able to identify `13` and `22` logical parameters which actually influence the immune response (**IIR**) and inflammation (**INFL**) phenotypes respectively. Three of these (`TREML4`, `Nsp3`, and `Azithromycin_drug`) influence both phenotypes. Based on these parameters, we were able to construct decision trees which fully characterise the expression of phenotypes by this network.
#
# In the tree describing the **IIR** phenotype, we can observe that `Azithromycin_drug` always activates immune response. Meanwhile, in its absence, `Nsp3` (a prominent component of most coronaviruses) enables conditions in which immune response is inactive. Subsequently, other virus proteins (`Nsp*` and `Orf*`) further inhibit the immune response.
#
# Similarly, for the inflammation phenotype, we see `MNS_drug` playing a crucial role by counteracting the influence of the envelope protein `E` as a cause of inflammation. Interestingly, in this case, `Nsp3` actually acts as an inhibitor, with `Viral_dsRNA_rna_endosome` playing a crucial role in the activation of inflammation in the absence of `Nsp3`.
#
# Finally, we can conclude that in this network, `GRL0617_drug` does not have any meaningful impact on either the emergence of multi-stability, or the expression of network phenotypes.

# %% [markdown]
# ### References
#
# \[1] Hojyo, Shintaro, et al. "How COVID-19 induces cytokine storm with high mortality." Inflammation and regeneration 40.1 (2020): 1-7.
#
# \[2] Ostaszewski, Marek, et al. "COVID-19 Disease Map, building a computational repository of SARS-CoV-2 virus-host interaction mechanisms." Scientific data 7.1 (2020): 1-4.
#
# \[3] Aghamiri, Sara Sadat, et al. "Automated inference of Boolean models from molecular interaction maps using CaSQ." Bioinformatics 36.16 (2020): 4473-4482.
